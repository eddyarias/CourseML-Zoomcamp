# %%
import pandas as pd

# %%
df = pd.read_csv("datasets/user_fake_authentic_2class.csv")

# %%
df
# Out:
#         pos   flw   flg   bl  pic  lin   cl        cz     ni        erl   erc  \
# 0        44    48   325   33    1    0   12  0.000000  0.000   0.000000  0.00
# 1        10    66   321  150    1    0  213  0.000000  1.000  14.390000  1.97
# 2        33   970   308  101    1    1  436  0.000000  1.000  10.100000  0.30
# 3        70    86   360   14    1    0    0  1.000000  0.000   0.780000  0.06
# 4         3    21   285   73    1    0   93  0.000000  0.000  14.290000  0.00
# ...     ...   ...   ...  ...  ...  ...  ...       ...    ...        ...   ...
# 65321    13   145   642    0    1    0    7  0.461538  0.000  14.270000  0.58
# 65322   652  3000  1300  146    1    1  384  0.000000  0.389   8.520000  0.13
# 65323  1500  3700  3200  147    1    1  129  0.000000  0.111   9.390000  0.31
# 65324   329  1500  1800  218    1    1  290  0.055556  0.000   6.350000  0.26
# 65325   206   659   608   27    1    0   77  0.000000  0.333  25.549999  0.53
#
# ...

# %%
df['class'].value_counts()
# Out:
# class
# f    32866
# r    32460
# Name: count, dtype: int64

# %%
df.describe()
# Out:
#                 pos           flw           flg            bl           pic  \
# count  65326.000000  6.532600e+04  65326.000000  65326.000000  65326.000000
# mean     176.571227  1.183077e+03   2310.519211     57.497061      0.951765
# std      723.470655  2.170802e+04   2592.096104     64.129260      0.214264
# min        0.000000  0.000000e+00      0.000000      0.000000      0.000000
# 25%        6.000000  1.230000e+02    394.000000      0.000000      1.000000
# 50%       30.000000  3.380000e+02    995.000000     32.000000      1.000000
# 75%      124.000000  8.170000e+02   3600.000000    110.000000      1.000000
# max    76200.000000  3.900000e+06   8800.000000    555.000000      1.000000
#
#                 lin            cl            cz            ni           erl  \
# count  65326.000000  65326.000000  65326.000000  65326.000000  65326.000000
# mean       0.281925    136.520344      0.250012      0.193229     19.146641
# ...

# %%
from sklearn.model_selection import train_test_split

df_full_train, df_test = train_test_split(df, test_size=0.2, random_state=11)
df_train, df_val = train_test_split(df_full_train, test_size=0.25, random_state=11)

# %%
print(df_train,
df_val,
df_test)
# Out:
#        pos   flw   flg   bl  pic  lin   cl        cz     ni        erl   erc  \
# 38814   10   276  1900   52    1    0   74  0.000000  0.700  34.669998  1.20
# 42534   93   982   892   86    1    1  168  0.000000  0.229  11.180000  0.38
# 16005    6     4   107    0    1    0    0  1.000000  0.000  33.330002  0.00
# 41565   58   178   280   54    1    0   77  0.166667  0.056  27.900000  1.12
# 5667     1    89   807    0    1    0  129  0.000000  0.000  44.939999  2.25
# ...    ...   ...   ...  ...  ...  ...  ...       ...    ...        ...   ...
# 23662   59   150  7200  209    1    0   25  0.666667  0.167  64.300003  1.85
# 921     90   689  2600   16    1    0  257  0.000000  0.111   2.560000  0.22
# 48488  108  2100  2900   44    1    1  140  0.000000  0.167   3.080000  0.07
# 5618   214   445  3700   31    1    0  283  0.000000  0.444   5.570000  0.64
# 19617   36    83    78   33    1    0   20  0.277778  0.000   2.410000  0.00
#
# ...

# %%
df_train = df_train.reset_index(drop=True)
df_val = df_val.reset_index(drop=True)
df_test = df_test.reset_index(drop=True)

# %%
print(df_train,
df_val,
df_test)
# Out:
#        pos   flw   flg   bl  pic  lin   cl        cz     ni        erl   erc  \
# 0       10   276  1900   52    1    0   74  0.000000  0.700  34.669998  1.20
# 1       93   982   892   86    1    1  168  0.000000  0.229  11.180000  0.38
# 2        6     4   107    0    1    0    0  1.000000  0.000  33.330002  0.00
# 3       58   178   280   54    1    0   77  0.166667  0.056  27.900000  1.12
# 4        1    89   807    0    1    0  129  0.000000  0.000  44.939999  2.25
# ...    ...   ...   ...  ...  ...  ...  ...       ...    ...        ...   ...
# 39190   59   150  7200  209    1    0   25  0.666667  0.167  64.300003  1.85
# 39191   90   689  2600   16    1    0  257  0.000000  0.111   2.560000  0.22
# 39192  108  2100  2900   44    1    1  140  0.000000  0.167   3.080000  0.07
# 39193  214   445  3700   31    1    0  283  0.000000  0.444   5.570000  0.64
# 39194   36    83    78   33    1    0   20  0.277778  0.000   2.410000  0.00
#
# ...

# %%
y_train = (df_train['class'] == 'f').astype('int').values
y_val = (df_val['class'] == 'f').astype('int').values
y_test = (df_test['class'] == 'f').astype('int').values

# %% [markdown]
# # r = 0 = real
# # f = 1 =falso

# %%
y_train
# Out:
# array([0, 0, 1, ..., 0, 1, 1])

# %%
del df_train['class']
del df_val['class']
del df_test['class']

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.feature_extraction import DictVectorizer
from sklearn.metrics import roc_auc_score
from sklearn.tree import export_text

# %%
X_train = df_train

# %%
dt = DecisionTreeClassifier()
dt.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
X_val = df_val

# %%
y_pred = dt.predict_proba(X_val)[:, 1]
roc_auc_score(y_val, y_pred)
# Out:
# 0.8574257271218388

# %%
y_pred = dt.predict_proba(X_train)[:, 1]
roc_auc_score(y_train, y_pred)
# Out:
# 1.0

# %%
dt = DecisionTreeClassifier(max_depth=12)
dt.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=12)

# %%
y_pred = dt.predict_proba(X_train)[:, 1]
auc = roc_auc_score(y_train, y_pred)
print('train:', auc)

y_pred = dt.predict_proba(X_val)[:, 1]
auc = roc_auc_score(y_val, y_pred)
print('val:', auc)
# Out:
# train: 0.9716084093113749
# val: 0.9325249530643458

# %%
import matplotlib.pyplot as plt

max_depths = range(1, 30)  # Profundidades de 1 a 12
train_aucs = []
val_aucs = []

for max_depth in max_depths:
    dt = DecisionTreeClassifier(max_depth=max_depth)
    dt.fit(X_train, y_train)

    # AUC para el conjunto de entrenamiento
    y_pred_train = dt.predict_proba(X_train)[:, 1]
    train_auc = roc_auc_score(y_train, y_pred_train)
    train_aucs.append(train_auc)

    # AUC para el conjunto de validación
    y_pred_val = dt.predict_proba(X_val)[:, 1]
    val_auc = roc_auc_score(y_val, y_pred_val)
    val_aucs.append(val_auc)

# Graficar los resultados
plt.figure(figsize=(10, 6))
plt.plot(max_depths, train_aucs, label='AUC Train', marker='o')
plt.plot(max_depths, val_aucs, label='AUC Val', marker='o')
plt.title('AUC en función de la profundidad del árbol')
plt.xlabel('Profundidad máxima del árbol')
plt.ylabel('AUC')
plt.xticks(max_depths)
plt.legend()
plt.grid()
plt.show()

# %%
from sklearn.metrics import confusion_matrix, roc_curve, det_curve
import seaborn as sns

dt = DecisionTreeClassifier(max_depth=9)
dt.fit(X_train, y_train)

# Realizar predicciones
y_pred = dt.predict(X_val)

# Crear la matriz de confusión
cm = confusion_matrix(y_val, y_pred)

# Definir las etiquetas
labels = ['Perfil Real (0)', 'Perfil Falso (1)']

# Graficar la matriz de confusión
plt.figure(figsize=(3, 3))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False,
            xticklabels=labels, yticklabels=labels)

# Personalizar el gráfico
plt.title('Matriz de Confusión')
plt.xlabel('Predicción')
plt.ylabel('Realidad')
plt.show()

# %%
# Realizar predicciones y obtener probabilidades
y_scores = dt.predict_proba(X_val)[:, 1]

# Obtener FPR y TPR
fpr, tpr, thresholds = roc_curve(y_val, y_scores, pos_label=1)

# Calcular FNR
fnr = 1 - tpr  # Tasa de Falsos Negativos

# Graficar la curva DET
plt.figure(figsize=(8, 6))
plt.plot(fpr, fnr, marker='o', color='blue', label='Curva DET')
plt.title('Curva DET (Detection Error Tradeoff)')
plt.xlabel('Tasa de Falsos Positivos (FPR)')
plt.ylabel('Tasa de Falsos Negativos (FNR)')
plt.xscale('log')
plt.yscale('log')
plt.grid(True, which="both", ls="--")

# Añadir línea de referencia (error igual)
plt.plot([0.001, 1], [0.001, 1], color='red', linestyle='--', label='Error Igual')

plt.legend()
plt.show()
