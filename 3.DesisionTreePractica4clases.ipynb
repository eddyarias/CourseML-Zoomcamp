# %%
import pandas as pd

# %%
df = pd.read_csv("datasets/user_fake_authentic_4class.csv")

# %%
df
# Out:
#        pos   flw   flg   bl  pic  lin   cl        cz     ni        erl   erc  \
# 0       69   541   440  293    1    0  223  0.000000  0.111  10.120000  0.50
# 1        9   783   803   76    1    0  101  0.000000  0.000  19.820000  1.99
# 2      390  1200   925  103    1    0  723  0.000000  0.000  11.540000  0.76
# 3      138  1100  1000   40    1    0   24  0.166667  0.167  20.440001  1.61
# 4        1   228   487   84    1    0   30  0.000000  0.000   9.210000  1.75
# ...    ...   ...   ...  ...  ...  ...  ...       ...    ...        ...   ...
# 43302   34   421   705    0    1    0    0  1.000000  0.333  13.130000  0.01
# 43303    3    26   124    0    1    0    0  1.000000  0.000  20.510000  1.28
# 43304   10   323  1500    0    1    0    0  1.000000  0.100   4.020000  0.15
# 43305    3   317  1000    0    1    0   12  0.333333  0.333  13.880000  0.63
# 43306  154  1900  6300  353    1    0  285  0.000000  0.389   5.940000  0.07
#
# ...

# %%
df['class'].value_counts()
# Out:
# class
# a    12054
# i    10549
# r    10441
# s    10263
# Name: count, dtype: int64

# %%
df.describe()
# Out:
#                 pos           flw           flg            bl           pic  \
# count  43307.000000  4.330700e+04  43307.000000  43307.000000  43307.000000
# mean     152.551851  8.274772e+02   2817.928210     46.263260      0.932644
# std      701.720040  1.250388e+04   2806.099606     60.603408      0.250641
# min        0.000000  0.000000e+00      0.000000      0.000000      0.000000
# 25%        4.000000  1.070000e+02    483.000000      0.000000      1.000000
# 50%       22.000000  2.890000e+02   1400.000000     13.000000      1.000000
# 75%      102.000000  7.125000e+02   6100.000000     85.000000      1.000000
# max    76200.000000  1.900000e+06   7800.000000    555.000000      1.000000
#
#                 lin            cl            cz            ni           erl  \
# count  43307.000000  43307.000000  43307.000000  43307.000000  43307.000000
# mean       0.142448    120.867897      0.291397      0.184412     20.404906
# ...

# %%
from sklearn.model_selection import train_test_split

df_full_train, df_test = train_test_split(df, test_size=0.2, random_state=11)
df_train, df_val = train_test_split(df_full_train, test_size=0.25, random_state=11)

# %%
print(df_train,
df_val,
df_test)
# Out:
#        pos   flw   flg   bl  pic  lin   cl        cz     ni    erl   erc  \
# 21801  167  1200  1900  158    1    0   80  0.000000  0.278   1.57  0.09
# 19454  132   680  1700   60    1    0   55  0.111111  0.222   2.53  0.06
# 25368   16   232   864    0    1    0   39  0.437500  0.125   7.19  0.40
# 27307  696   781  2200  176    1    0  488  0.444444  0.111   0.16  0.01
# 8170    36   791  2600   62    1    0   23  0.166667  0.389  17.84  0.60
# ...    ...   ...   ...  ...  ...  ...  ...       ...    ...    ...   ...
# 618     39   304   874  147    1    0  101  0.000000  0.278  11.17  0.68
# 17713   45  1100  1900    0    1    0  370  0.500000  0.000   0.35  0.02
# 580     27   208   219    0    1    0   22  0.111111  0.222  15.89  0.75
# 23787  287  1700  7500  143    1    0   90  0.111111  0.278   0.23  0.00
# 1845    55   300   692    0    1    0   41  0.333333  0.111  15.09  0.67
#
#           lt     hc     pr     fo        cs           pi class
# ...

# %%
df_train = df_train.reset_index(drop=True)
df_val = df_val.reset_index(drop=True)
df_test = df_test.reset_index(drop=True)

# %%
print(df_train,
df_val,
df_test)
# Out:
#        pos   flw   flg   bl  pic  lin   cl        cz     ni    erl   erc  \
# 0      167  1200  1900  158    1    0   80  0.000000  0.278   1.57  0.09
# 1      132   680  1700   60    1    0   55  0.111111  0.222   2.53  0.06
# 2       16   232   864    0    1    0   39  0.437500  0.125   7.19  0.40
# 3      696   781  2200  176    1    0  488  0.444444  0.111   0.16  0.01
# 4       36   791  2600   62    1    0   23  0.166667  0.389  17.84  0.60
# ...    ...   ...   ...  ...  ...  ...  ...       ...    ...    ...   ...
# 25978   39   304   874  147    1    0  101  0.000000  0.278  11.17  0.68
# 25979   45  1100  1900    0    1    0  370  0.500000  0.000   0.35  0.02
# 25980   27   208   219    0    1    0   22  0.111111  0.222  15.89  0.75
# 25981  287  1700  7500  143    1    0   90  0.111111  0.278   0.23  0.00
# 25982   55   300   692    0    1    0   41  0.333333  0.111  15.09  0.67
#
#           lt     hc     pr     fo        cs           pi class
# ...

# %%
y_train = (df_train['class'] == 'f').astype('int').values
y_val = (df_val['class'] == 'f').astype('int').values
y_test = (df_test['class'] == 'f').astype('int').values

# %%
y_train = df_train['class']
y_val = df_val['class']
y_test = df_test['class']

# %% [markdown]
# # r = 0 = real
# # f = 1 =falso

# %%
y_train
# Out:
# 0        a
# 1        a
# 2        a
# 3        s
# 4        r
#         ..
# 25978    r
# 25979    s
# 25980    r
# 25981    a
# 25982    r
# Name: class, Length: 25983, dtype: object

# %%
del df_train['class']
del df_val['class']
del df_test['class']

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.feature_extraction import DictVectorizer
from sklearn.metrics import roc_auc_score
from sklearn.tree import export_text

# %%
X_train = df_train

# %%
dt = DecisionTreeClassifier()
dt.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
X_val = df_val

# %%
y_pred_proba = dt.predict_proba(X_val)
roc_auc = roc_auc_score(y_val, y_pred_proba, multi_class='ovr')  # O 'multi_class='ovo''
print(roc_auc)
# Out:
# 0.9102394813928938

# %%
y_pred = dt.predict_proba(X_train)
roc_auc_score(y_train, y_pred, multi_class='ovr')
print(roc_auc_score)
# Out:
# <function roc_auc_score at 0x000001C82E41AA20>

# %%
dt = DecisionTreeClassifier(max_depth=12)
dt.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=12)

# %%
y_pred = dt.predict_proba(X_train)
auc = roc_auc_score(y_train, y_pred, multi_class='ovr')
print('train:', auc)

y_pred = dt.predict_proba(X_val)
auc = roc_auc_score(y_val, y_pred, multi_class='ovr')
print('val:', auc)
# Out:
# train: 0.9937101738249311
# val: 0.9595533450285849

# %%
import matplotlib.pyplot as plt

max_depths = range(1, 30)  # Profundidades de 1 a 12
train_aucs = []
val_aucs = []

for max_depth in max_depths:
    dt = DecisionTreeClassifier(max_depth=max_depth)
    dt.fit(X_train, y_train)

    # AUC para el conjunto de entrenamiento
    y_pred_train = dt.predict_proba(X_train)
    train_auc = roc_auc_score(y_train, y_pred_train, multi_class='ovr')
    train_aucs.append(train_auc)

    # AUC para el conjunto de validación
    y_pred_val = dt.predict_proba(X_val)
    val_auc = roc_auc_score(y_val, y_pred_val, multi_class='ovr')
    val_aucs.append(val_auc)

# Graficar los resultados
plt.figure(figsize=(10, 6))
plt.plot(max_depths, train_aucs, label='AUC Train', marker='o')
plt.plot(max_depths, val_aucs, label='AUC Val', marker='o')
plt.title('AUC en función de la profundidad del árbol')
plt.xlabel('Profundidad máxima del árbol')
plt.ylabel('AUC')
plt.xticks(max_depths)
plt.legend()
plt.grid()
plt.show()

# %%
from sklearn.metrics import confusion_matrix, roc_curve, det_curve
import seaborn as sns

dt = DecisionTreeClassifier(max_depth=9)
dt.fit(X_train, y_train)

# Realizar predicciones
y_pred = dt.predict(X_val)


# AUC para el conjunto de entrenamiento
y_pred_train = dt.predict_proba(X_train)
train_auc = roc_auc_score(y_train, y_pred_train, multi_class='ovr')
print("Train Auc: ",train_auc)

# AUC para el conjunto de validación
y_pred_val = dt.predict_proba(X_val)
val_auc = roc_auc_score(y_val, y_pred_val, multi_class='ovr')
print("Val auc: ",val_auc)
# Crear la matriz de confusión
cm = confusion_matrix(y_val, y_pred)

# Graficar la matriz de confusión
plt.figure(figsize=(3, 3))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False)

# Personalizar el gráfico
plt.title('Matriz de Confusión')
plt.xlabel('Predicción')
plt.ylabel('Realidad')
plt.show()
# Out:
# Train Auc:  0.9857801633636912
# Val auc:  0.9739082099890126

# %%
# Obtener las probabilidades para cada clase
y_pred_proba = dt.predict_proba(X_val)

# Calcular ROC AUC para multiclase
roc_auc = roc_auc_score(y_val, y_pred_proba, multi_class='ovr')  # O 'multi_class='ovo''
print('ROC AUC:', roc_auc)

# Inicializar listas para FPR y FNR
fpr = []
fnr = []
n_classes = y_pred_proba.shape[1]

# Calcular FPR y FNR para cada clase
for i in range(n_classes):
    # Obtener la curva ROC para cada clase
    fpr_i, tpr_i, thresholds = roc_curve(y_val, y_pred_proba[:, i], pos_label=i)
    
    # Calcular FNR
    fnr_i = 1 - tpr_i
    
    # Almacenar FPR y FNR
    fpr.append(fpr_i)
    fnr.append(fnr_i)

# Graficar la curva DET
plt.figure(figsize=(8, 6))

for i in range(n_classes):
    plt.plot(fpr[i], fnr[i], marker='o', label=f'Clase {i}')

plt.title('Curva DET (Detection Error Tradeoff) por Clase')
plt.xlabel('Tasa de Falsos Positivos (FPR)')
plt.ylabel('Tasa de Falsos Negativos (FNR)')
plt.xscale('log')
plt.yscale('log')
plt.grid(True, which="both", ls="--")

# Añadir línea de referencia (error igual)
plt.plot([0.001, 1], [0.001, 1], color='red', linestyle='--', label='Error Igual')

plt.legend()
plt.show()
# Out:
# ROC AUC: 0.9739082099890126
# c:\Anaconda3\Lib\site-packages\sklearn\metrics\_ranking.py:1146: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   warnings.warn(
# c:\Anaconda3\Lib\site-packages\sklearn\metrics\_ranking.py:1146: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   warnings.warn(
# c:\Anaconda3\Lib\site-packages\sklearn\metrics\_ranking.py:1146: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   warnings.warn(
# c:\Anaconda3\Lib\site-packages\sklearn\metrics\_ranking.py:1146: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   warnings.warn(

# %%
print(export_text(dt))
# Out:
# |--- feature_0 <= 8.50
# |   |--- feature_6 <= 5.50
# |   |   |--- feature_10 <= 0.45
# |   |   |   |--- feature_14 <= 0.17
# |   |   |   |   |--- feature_0 <= 7.50
# |   |   |   |   |   |--- class: i
# |   |   |   |   |--- feature_0 >  7.50
# |   |   |   |   |   |--- feature_5 <= 0.50
# |   |   |   |   |   |   |--- class: i
# |   |   |   |   |   |--- feature_5 >  0.50
# |   |   |   |   |   |   |--- feature_2 <= 359.00
# |   |   |   |   |   |   |   |--- class: i
# |   |   |   |   |   |   |--- feature_2 >  359.00
# |   |   |   |   |   |   |   |--- class: r
# |   |   |   |--- feature_14 >  0.17
# |   |   |   |   |--- class: s
# |   |   |--- feature_10 >  0.45
# |   |   |   |--- feature_2 <= 2150.00
# |   |   |   |   |--- feature_2 <= 490.50
# |   |   |   |   |   |--- feature_1 <= 62.50
# |   |   |   |   |   |   |--- feature_2 <= 73.50
# |   |   |   |   |   |   |   |--- feature_6 <= 0.50
# |   |   |   |   |   |   |   |   |--- feature_9 <= 7.32
# ...

# %%
from sklearn.ensemble import RandomForestClassifier

scores = []

for n in range(10, 201, 10):
    rf = RandomForestClassifier(n_estimators=n, random_state=1, n_jobs=-1, verbose=1)
    rf.fit(X_train, y_train)

    y_pred = rf.predict_proba(X_val)
    auc = roc_auc_score(y_val, y_pred, multi_class='ovr')
    
    scores.append((n, auc))
# Out:
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   6 out of  10 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:    0.0s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done   6 out of  10 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=8)]: Done  10 out of  10 | elapsed:    0.0s finished
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  20 out of  20 | elapsed:    0.1s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  20 out of  20 | elapsed:    0.0s finished
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    0.2s finished
# ...

# %% [markdown]
# 3 m 41.7s sin workers adicionales
#     con workers

# %%
df_scores = pd.DataFrame(scores, columns=['n_estimators', 'auc'])
plt.plot(df_scores.n_estimators, df_scores.auc)

# %%
df_scores
# Out:
#     n_estimators       auc
# 0             10  0.982184
# 1             20  0.985900
# 2             30  0.986979
# 3             40  0.987504
# 4             50  0.987833
# 5             60  0.988004
# 6             70  0.988126
# 7             80  0.988202
# 8             90  0.988264
# 9            100  0.988228
# 10           110  0.988272
# 11           120  0.988301
# 12           130  0.988331
# 13           140  0.988389
# 14           150  0.988424
# 15           160  0.988477
# 16           170  0.988478
# 17           180  0.988449
# 18           190  0.988467
# 19           200  0.988508

# %%
scores = []

for d in [5, 10, 15]:
    for n in range(10, 201, 10):
        rf = RandomForestClassifier(n_estimators=n,
                                    max_depth=d,
                                    random_state=1, n_jobs=-1, verbose=1)
        rf.fit(X_train, y_train)

        y_pred = rf.predict_proba(X_val)
        auc = roc_auc_score(y_val, y_pred, multi_class='ovr')

        scores.append((d, n, auc))

columns = ['max_depth', 'n_estimators', 'auc']
df_scores = pd.DataFrame(scores, columns=columns)

for d in [5, 10, 15]:
    df_subset = df_scores[df_scores.max_depth == d]
    
    plt.plot(df_subset.n_estimators, df_subset.auc,
             label='max_depth=%d' % d)

plt.legend()
# Out:
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   6 out of  10 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:    0.0s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done   6 out of  10 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=8)]: Done  10 out of  10 | elapsed:    0.0s finished
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  20 out of  20 | elapsed:    0.0s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  20 out of  20 | elapsed:    0.0s finished
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    0.0s finished
# ...

# %%
rf = RandomForestClassifier(n_estimators=50,
                                    max_depth=15,
                                    random_state=1, n_jobs=-1, verbose=1)
rf.fit(X_train, y_train)

y_pred = rf.predict_proba(X_val)
auc = roc_auc_score(y_val, y_pred, multi_class='ovr')
# Out:
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-1)]: Done  50 out of  50 | elapsed:    0.5s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done  50 out of  50 | elapsed:    0.0s finished

# %%
print(auc)
# Out:
# 0.9875701969665299

# %%
# Realizar predicciones
y_pred = rf.predict(X_val)


# AUC para el conjunto de entrenamiento
y_pred_train = rf.predict_proba(X_train)
train_auc = roc_auc_score(y_train, y_pred_train, multi_class='ovr')
print("Train Auc: ",train_auc)

# AUC para el conjunto de validación
y_pred_val = rf.predict_proba(X_val)
val_auc = roc_auc_score(y_val, y_pred_val, multi_class='ovr')
print("Val auc: ",val_auc)
# Crear la matriz de confusión
cm = confusion_matrix(y_val, y_pred)

# Graficar la matriz de confusión
plt.figure(figsize=(3, 3))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False)

# Personalizar el gráfico
plt.title('Matriz de Confusión')
plt.xlabel('Predicción')
plt.ylabel('Realidad')
plt.show()
# Out:
# Train Auc:  0.9989223827145797
# Val auc:  0.9875701969665299
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done  50 out of  50 | elapsed:    0.0s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done  50 out of  50 | elapsed:    0.0s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done  50 out of  50 | elapsed:    0.0s finished

# %%
#Hiperparametro min_samples_leaf

# %%
scores = []

for s in [1, 3, 5, 10, 50]:
    for n in range(10, 100):

        rf = RandomForestClassifier(n_estimators=n,            # Número de árboles (estimadores)
                                    max_depth=15,              # Profundidad máxima de cada árbol
                                    min_samples_leaf=s,        # Mínimo número de muestras por hoja
                                    random_state=1,            # Fijar semilla para reproducibilidad
                                    n_jobs=-1,                 # Utilizar todos los núcleos del CPU
                                    verbose=1)                 # Mostrar el progreso del entrenamiento)
        rf.fit(X_train, y_train)

        y_pred = rf.predict_proba(X_val)
        auc = roc_auc_score(y_val, y_pred, multi_class='ovr')

        scores.append((s, n, auc))

columns = ['min_samples_leaf', 'n_estimators', 'auc']
df_scores = pd.DataFrame(scores, columns=columns)
# Out:
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   6 out of  10 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:    0.0s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done   6 out of  10 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=8)]: Done  10 out of  10 | elapsed:    0.0s finished
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   8 out of  11 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  11 out of  11 | elapsed:    0.0s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done   8 out of  11 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=8)]: Done  11 out of  11 | elapsed:    0.0s finished
# ...

# %%
df_scores.hist()
# Out:
# array([[<Axes: title={'center': 'min_samples_leaf'}>,
#         <Axes: title={'center': 'n_estimators'}>],
#        [<Axes: title={'center': 'auc'}>, <Axes: >]], dtype=object)

# %%
df_scores.max()
# Out:
# min_samples_leaf     50.000000
# n_estimators        200.000000
# auc                   0.988431
# dtype: float64

# %%
colors = ['black', 'blue', 'orange', 'red', 'grey']
values = [1, 3, 5, 10, 50]

for s, col in zip(values, colors):
    df_subset = df_scores[df_scores.min_samples_leaf == s]
    
    plt.plot(df_subset.n_estimators, df_subset.auc,
             color=col,
             label='min_samples_leaf=%d' % s)

plt.legend()

# %%
rf = RandomForestClassifier(n_estimators=125,
                                max_depth=15,
                                min_samples_leaf=3,
                                random_state=1,
                                n_jobs=-1,
                                verbose=1)
rf.fit(X_train, y_train)
y_pred = rf.predict_proba(X_val)
auc = roc_auc_score(y_val, y_pred, multi_class='ovr')
print("Auc: ", auc)
# Out:
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    0.2s
# Auc:  0.9883084893301021
# [Parallel(n_jobs=-1)]: Done 125 out of 125 | elapsed:    0.8s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 125 out of 125 | elapsed:    0.0s finished

# %%
# Realizar predicciones
y_pred = rf.predict(X_val)


# AUC para el conjunto de entrenamiento
y_pred_train = rf.predict_proba(X_train)
train_auc = roc_auc_score(y_train, y_pred_train, multi_class='ovr')
print("Train Auc: ",train_auc)

# AUC para el conjunto de validación
y_pred_val = rf.predict_proba(X_val)
val_auc = roc_auc_score(y_val, y_pred_val, multi_class='ovr')
print("Val auc: ",val_auc)
# Crear la matriz de confusión
cm = confusion_matrix(y_val, y_pred)

# Convertir la matriz de confusión a porcentajes
cm_norm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

# Graficar la matriz de confusión con porcentajes
plt.figure(figsize=(5, 5))
sns.heatmap(cm_norm, annot=True, fmt='.2%', cmap='Blues', cbar=False)

# Personalizar el gráfico
plt.title('Matriz de Confusión (Porcentajes)')
plt.xlabel('Predicción')
plt.ylabel('Realidad')
plt.show()
# Out:
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 496 out of 496 | elapsed:    0.1s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=8)]: Done 496 out of 496 | elapsed:    0.3s finished
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# Train Auc:  0.9982389800502636
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    0.1s
# ...
